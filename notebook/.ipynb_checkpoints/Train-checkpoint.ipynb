# %%
import os
from albumentations import *

import segmentation_models as sm
import cv2
import numpy as np 

import pandas as pd
import tensorflow as tf

import keras
from keras.optimizers import *
from keras import backend as K
from keras import Input
from keras.models import Model
from keras.callbacks import *
from keras.metrics import *
from keras.utils import *

from tensorflow import set_random_seed
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Segmentation Models: using `keras` framework.

# %%
'''
    Training config
'''
IMG_SIZE = (256, 256, 3)
EPOCHS = 50
BATCH_SIZE = 16
MODEL_NAME = 'resnet34'

TRAINING_IMAGE_FOLDER = '../data/stage1_train'
TRAINING_CSV = '../data/stage1_train_labels.csv'

generator = Compose([
                    HorizontalFlip(),
                    VerticalFlip(),
                    ShiftScaleRotate(),
                    OneOf([
                        RandomBrightness(),
                        RandomContrast(),
                        RandomGamma(),
                        CLAHE()
                    ])], 
            additional_targets={'mask': 'mask'})

# %%
train_df = pd.read_csv(TRAINING_CSV)

# %%
'''
    RLE Utilities functions
'''
def rle_encoding(mask):
    
    pixels = mask.T.flatten()
    pixels = np.concatenate([[0], pixels,[0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    if len(runs) % 2:
        runs = np.append(runs,len(pixels))
    runs[1::2] -= runs[0::2]
    
    return ' '.join(str(x) for x in runs)

def rle_decoding(rle, mask_shape = (256,256)):
    strs = rle.split(' ')
    starts = np.asarray(strs[0::2], dtype = int) - 1
    lengths = np.asarray(strs[1::2], dtype = int)
    ends = starts + lengths
    
    mask = np.zeros(mask_shape[0] * mask_shape[1], dtype = np.uint8)
    for s,e in zip(starts, ends):
        mask[s:e] = 1
    return mask.reshape((mask_shape[0], mask_shape[1]), order = 'F')

# %%
'''
    Metric and loss function
'''
def Dice_Coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 2*intersection / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def Dice_Loss(y_true, y_pred):
    return 1 - Dice_Coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    return keras.losses.binary_crossentropy(y_true, y_pred) + Dice_Loss(y_true, y_pred)

# %%
class Datagen(Sequence):
    def __init__(self, list_id, image_folder, generator = None, batch_size=BATCH_SIZE):
        self.list_id = list_id
        self.image_folder = image_folder
        self.generator = generator
        self.batch_size = batch_size
        
    def on_epoch_end(self):
        np.random.shuffle(self.list_id)
        
    def __len__(self):
        return int(np.floor(len(self.list_id) / self.batch_size)) 
        
    def __getitem__(self, index):
        list_id = self.list_id[index*self.batch_size:(index + 1)*self.batch_size]
        images = np.empty((len(list_id), *IMG_SIZE), dtype=np.uint8)
        masks = np.empty((len(list_id), IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.uint8)
        for i, item in enumerate(list_id):
            path = os.path.join(self.image_folder, item)
            image_path = os.path.join(path, 'images', item + '.png') 
            image = cv2.imread(image_path)
            image = cv2.resize(image, (IMG_SIZE[1], IMG_SIZE[0]))
            images[i] = image
            
            masks_path = os.path.join(path, 'masks')
            masks_file = os.listdir(masks_path)
            for mask in masks_file:
                mask_img = cv2.imread(os.path.join(masks_path, mask), cv2.IMREAD_GRAYSCALE)
                mask_img = cv2.resize(mask_img, (IMG_SIZE[1], IMG_SIZE[0]))
                masks[i,:,:,0] += mask_img
                
            if self.generator is not None:
                for i in range(len(list_id)):
                    augmented = self.generator(image=images[i], mask=masks[i])
                    images[i] = augmented['image']
                    masks[i] = augmented['mask']
                
        return images.astype(np.float32) / 255., masks.astype(np.float32) / 255.

# %%
list_item = os.listdir(TRAINING_IMAGE_FOLDER)
from sklearn.model_selection import train_test_split
train_list, test_list = train_test_split(list_item, test_size=0.1)
train_gen = Datagen(train_list, TRAINING_IMAGE_FOLDER, generator)
valid_gen = Datagen(test_list, TRAINING_IMAGE_FOLDER)

# %%
img, mask = train_gen.__getitem__(0)
img = img*255.
img = img.astype('uint8')
mask = mask.reshape(BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1])
fig, ax = plt.subplots(nrows=1, ncols=8, figsize=(20,4))
i = 0
while i < 8:
    ax[i].imshow(img[i])
    ax[i + 1].imshow(mask[i])
    ax[i].axis('off')
    ax[i + 1].axis('off')
    i += 2

# %%
callbacks = [keras.callbacks.ReduceLROnPlateau(monitor='val_Dice_Coef',
                                               mode='max',
                                               verbose=1,
                                               patients=10,
                                               min_lr=1e-5),
             keras.callbacks.ModelCheckpoint('../data/resnet34.h5',
                                         monitor='val_Dice_Coef', 
                                         verbose=1, 
                                         save_best_only=True, 
                                         save_weights_only=True, 
                                         mode='max', 
                                         period=1)]

model = sm.Unet(MODEL_NAME, input_shape=IMG_SIZE, classes=1, activation='sigmoid')

model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[Dice_Coef])
model.fit_generator(train_gen, 
                    steps_per_epoch=len(train_gen),
                    epochs=EPOCHS,
                    validation_data=valid_gen,
                    validation_steps=len(valid_gen),
                    callbacks=callbacks)
# Out:
# WARNING:tensorflow:From C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\quand\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 37/37 [==============================] - 34s 927ms/step - loss: 0.7584 - Dice_Coef: 0.5317 - val_loss: 0.8975 - val_Dice_Coef: 0.6729
#
# Epoch 00001: val_Dice_Coef improved from -inf to 0.67295, saving model to ../data/resnet34.h5
# Epoch 2/100
# 37/37 [==============================] - 25s 663ms/step - loss: 0.4058 - Dice_Coef: 0.7428 - val_loss: 1.0712 - val_Dice_Coef: 0.5913
#
# Epoch 00002: val_Dice_Coef did not improve from 0.67295
# Epoch 3/100
# 37/37 [==============================] - 33s 898ms/step - loss: 0.3244 - Dice_Coef: 0.7985 - val_loss: 0.4814 - val_Dice_Coef: 0.7208
#
# Epoch 00003: val_Dice_Coef improved from 0.67295 to 0.72077, saving model to ../data/resnet34.h5
# Epoch 4/100
# 37/37 [==============================] - 34s 912ms/step - loss: 0.3038 - Dice_Coef: 0.8165 - val_loss: 0.2939 - val_Dice_Coef: 0.8101
#
# Epoch 00004: val_Dice_Coef improved from 0.72077 to 0.81007, saving model to ../data/resnet34.h5
# Epoch 5/100
# 37/37 [==============================] - 35s 952ms/step - loss: 0.2935 - Dice_Coef: 0.8229 - val_loss: 0.3407 - val_Dice_Coef: 0.7804
#
# Epoch 00005: val_Dice_Coef did not improve from 0.81007
# Epoch 6/100
# 37/37 [==============================] - 33s 904ms/step - loss: 0.2781 - Dice_Coef: 0.8339 - val_loss: 0.2204 - val_Dice_Coef: 0.8621
#
# Epoch 00006: val_Dice_Coef improved from 0.81007 to 0.86207, saving model to ../data/resnet34.h5
# Epoch 7/100
# 37/37 [==============================] - 33s 892ms/step - loss: 0.2588 - Dice_Coef: 0.8447 - val_loss: 0.2493 - val_Dice_Coef: 0.8435
#
# Epoch 00007: val_Dice_Coef did not improve from 0.86207
# Epoch 8/100
# 37/37 [==============================] - 34s 906ms/step - loss: 0.2771 - Dice_Coef: 0.8367 - val_loss: 0.2176 - val_Dice_Coef: 0.8673
#
# Epoch 00008: val_Dice_Coef improved from 0.86207 to 0.86731, saving model to ../data/resnet34.h5
# Epoch 9/100
# 37/37 [==============================] - 33s 903ms/step - loss: 0.2705 - Dice_Coef: 0.8385 - val_loss: 0.1959 - val_Dice_Coef: 0.8796
#
# Epoch 00009: val_Dice_Coef improved from 0.86731 to 0.87957, saving model to ../data/resnet34.h5
# Epoch 10/100
# 37/37 [==============================] - 35s 937ms/step - loss: 0.2767 - Dice_Coef: 0.8373 - val_loss: 0.2853 - val_Dice_Coef: 0.8145
#
# Epoch 00010: val_Dice_Coef did not improve from 0.87957
# Epoch 11/100
# 37/37 [==============================] - 35s 942ms/step - loss: 0.2733 - Dice_Coef: 0.8360 - val_loss: 0.3701 - val_Dice_Coef: 0.7887
#
# Epoch 00011: val_Dice_Coef did not improve from 0.87957
# Epoch 12/100
# 37/37 [==============================] - 34s 925ms/step - loss: 0.3059 - Dice_Coef: 0.8192 - val_loss: 0.2298 - val_Dice_Coef: 0.8551
#
# Epoch 00012: val_Dice_Coef did not improve from 0.87957
# Epoch 13/100
# 37/37 [==============================] - 34s 909ms/step - loss: 0.2687 - Dice_Coef: 0.8427 - val_loss: 0.2487 - val_Dice_Coef: 0.8436
#
# Epoch 00013: val_Dice_Coef did not improve from 0.87957
# Epoch 14/100
# 37/37 [==============================] - 33s 904ms/step - loss: 0.2750 - Dice_Coef: 0.8373 - val_loss: 0.2331 - val_Dice_Coef: 0.8553
#
# Epoch 00014: val_Dice_Coef did not improve from 0.87957
# Epoch 15/100
# 37/37 [==============================] - 33s 893ms/step - loss: 0.2647 - Dice_Coef: 0.8430 - val_loss: 0.2504 - val_Dice_Coef: 0.8628
#
# Epoch 00015: val_Dice_Coef did not improve from 0.87957
# Epoch 16/100
# 37/37 [==============================] - 33s 901ms/step - loss: 0.2596 - Dice_Coef: 0.8461 - val_loss: 0.2213 - val_Dice_Coef: 0.8564
#
# Epoch 00016: val_Dice_Coef did not improve from 0.87957
# Epoch 17/100
# 37/37 [==============================] - 33s 894ms/step - loss: 0.2591 - Dice_Coef: 0.8446 - val_loss: 0.2275 - val_Dice_Coef: 0.8637
#
# Epoch 00017: val_Dice_Coef did not improve from 0.87957
# Epoch 18/100
# 37/37 [==============================] - 33s 892ms/step - loss: 0.2507 - Dice_Coef: 0.8507 - val_loss: 0.2099 - val_Dice_Coef: 0.8678
#
# Epoch 00018: val_Dice_Coef did not improve from 0.87957
# Epoch 19/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2413 - Dice_Coef: 0.8560 - val_loss: 0.3224 - val_Dice_Coef: 0.8126
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_Dice_Coef did not improve from 0.87957
# Epoch 20/100
# 37/37 [==============================] - 33s 883ms/step - loss: 0.2345 - Dice_Coef: 0.8597 - val_loss: 0.1903 - val_Dice_Coef: 0.8844
#
# Epoch 00020: val_Dice_Coef improved from 0.87957 to 0.88440, saving model to ../data/resnet34.h5
# Epoch 21/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2263 - Dice_Coef: 0.8638 - val_loss: 0.1847 - val_Dice_Coef: 0.8867
#
# Epoch 00021: val_Dice_Coef improved from 0.88440 to 0.88669, saving model to ../data/resnet34.h5
# Epoch 22/100
# 37/37 [==============================] - 33s 901ms/step - loss: 0.2325 - Dice_Coef: 0.8611 - val_loss: 0.1762 - val_Dice_Coef: 0.8911
#
# Epoch 00022: val_Dice_Coef improved from 0.88669 to 0.89110, saving model to ../data/resnet34.h5
# Epoch 23/100
# 37/37 [==============================] - 33s 898ms/step - loss: 0.2294 - Dice_Coef: 0.8619 - val_loss: 0.1795 - val_Dice_Coef: 0.8864
#
# Epoch 00023: val_Dice_Coef did not improve from 0.89110
# Epoch 24/100
# 37/37 [==============================] - 33s 903ms/step - loss: 0.2270 - Dice_Coef: 0.8617 - val_loss: 0.1683 - val_Dice_Coef: 0.8933
#
# Epoch 00024: val_Dice_Coef improved from 0.89110 to 0.89329, saving model to ../data/resnet34.h5
# Epoch 25/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2325 - Dice_Coef: 0.8604 - val_loss: 0.1716 - val_Dice_Coef: 0.8927
#
# Epoch 00025: val_Dice_Coef did not improve from 0.89329
# Epoch 26/100
# 37/37 [==============================] - 33s 888ms/step - loss: 0.2287 - Dice_Coef: 0.8616 - val_loss: 0.1668 - val_Dice_Coef: 0.8949
#
# Epoch 00026: val_Dice_Coef improved from 0.89329 to 0.89494, saving model to ../data/resnet34.h5
# Epoch 27/100
# 37/37 [==============================] - 33s 880ms/step - loss: 0.2351 - Dice_Coef: 0.8606 - val_loss: 0.1702 - val_Dice_Coef: 0.8931
#
# Epoch 00027: val_Dice_Coef did not improve from 0.89494
# Epoch 28/100
# 37/37 [==============================] - 33s 888ms/step - loss: 0.2233 - Dice_Coef: 0.8655 - val_loss: 0.1695 - val_Dice_Coef: 0.8956
#
# Epoch 00028: val_Dice_Coef improved from 0.89494 to 0.89562, saving model to ../data/resnet34.h5
# Epoch 29/100
# 37/37 [==============================] - 33s 892ms/step - loss: 0.2231 - Dice_Coef: 0.8650 - val_loss: 0.1697 - val_Dice_Coef: 0.8934
#
# Epoch 00029: val_Dice_Coef did not improve from 0.89562
# Epoch 30/100
# 37/37 [==============================] - 34s 908ms/step - loss: 0.2245 - Dice_Coef: 0.8639 - val_loss: 0.1561 - val_Dice_Coef: 0.9012
#
# Epoch 00030: val_Dice_Coef improved from 0.89562 to 0.90116, saving model to ../data/resnet34.h5
# Epoch 31/100
# 37/37 [==============================] - 33s 904ms/step - loss: 0.2271 - Dice_Coef: 0.8638 - val_loss: 0.1689 - val_Dice_Coef: 0.8949
#
# Epoch 00031: val_Dice_Coef did not improve from 0.90116
# Epoch 32/100
# 37/37 [==============================] - 33s 885ms/step - loss: 0.2240 - Dice_Coef: 0.8644 - val_loss: 0.1662 - val_Dice_Coef: 0.8946
#
# Epoch 00032: val_Dice_Coef did not improve from 0.90116
# Epoch 33/100
# 37/37 [==============================] - 33s 887ms/step - loss: 0.2265 - Dice_Coef: 0.8638 - val_loss: 0.1667 - val_Dice_Coef: 0.8970
#
# Epoch 00033: val_Dice_Coef did not improve from 0.90116
# Epoch 34/100
# 37/37 [==============================] - 33s 898ms/step - loss: 0.2248 - Dice_Coef: 0.8640 - val_loss: 0.1660 - val_Dice_Coef: 0.8953
#
# Epoch 00034: val_Dice_Coef did not improve from 0.90116
# Epoch 35/100
# 37/37 [==============================] - 33s 899ms/step - loss: 0.2246 - Dice_Coef: 0.8658 - val_loss: 0.1676 - val_Dice_Coef: 0.8961
# Epoch 00035: val_Dice_Coef did not improve from 0.90116
# Epoch 36/100
# 37/37 [==============================] - 34s 907ms/step - loss: 0.2210 - Dice_Coef: 0.8674 - val_loss: 0.1611 - val_Dice_Coef: 0.8997
#
# Epoch 00036: val_Dice_Coef did not improve from 0.90116
# Epoch 37/100
# 37/37 [==============================] - 33s 894ms/step - loss: 0.2141 - Dice_Coef: 0.8706 - val_loss: 0.1714 - val_Dice_Coef: 0.8934
#
# Epoch 00037: val_Dice_Coef did not improve from 0.90116
# Epoch 38/100
# 37/37 [==============================] - 33s 894ms/step - loss: 0.2287 - Dice_Coef: 0.8625 - val_loss: 0.1691 - val_Dice_Coef: 0.8948
#
# Epoch 00038: val_Dice_Coef did not improve from 0.90116
# Epoch 39/100
# 37/37 [==============================] - 33s 895ms/step - loss: 0.2237 - Dice_Coef: 0.8666 - val_loss: 0.1644 - val_Dice_Coef: 0.8968
#
# Epoch 00039: val_Dice_Coef did not improve from 0.90116
# Epoch 40/100
# 37/37 [==============================] - 33s 898ms/step - loss: 0.2217 - Dice_Coef: 0.8670 - val_loss: 0.1676 - val_Dice_Coef: 0.8972
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00040: val_Dice_Coef did not improve from 0.90116
# Epoch 41/100
# 37/37 [==============================] - 34s 906ms/step - loss: 0.2180 - Dice_Coef: 0.8680 - val_loss: 0.1643 - val_Dice_Coef: 0.8975
#
# Epoch 00041: val_Dice_Coef did not improve from 0.90116
# Epoch 42/100
# 37/37 [==============================] - 33s 902ms/step - loss: 0.2140 - Dice_Coef: 0.8699 - val_loss: 0.1651 - val_Dice_Coef: 0.8983
#
# Epoch 00042: val_Dice_Coef did not improve from 0.90116
# Epoch 43/100
# 37/37 [==============================] - 33s 893ms/step - loss: 0.2180 - Dice_Coef: 0.8688 - val_loss: 0.1616 - val_Dice_Coef: 0.8974
#
# Epoch 00043: val_Dice_Coef did not improve from 0.90116
# Epoch 44/100
# 37/37 [==============================] - 33s 894ms/step - loss: 0.2191 - Dice_Coef: 0.8673 - val_loss: 0.1660 - val_Dice_Coef: 0.8985
#
# Epoch 00044: val_Dice_Coef did not improve from 0.90116
# Epoch 45/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2164 - Dice_Coef: 0.8703 - val_loss: 0.1666 - val_Dice_Coef: 0.8979
#
# Epoch 00045: val_Dice_Coef did not improve from 0.90116
# Epoch 46/100
# 37/37 [==============================] - 33s 891ms/step - loss: 0.2205 - Dice_Coef: 0.8675 - val_loss: 0.1527 - val_Dice_Coef: 0.9038
#
# Epoch 00046: val_Dice_Coef improved from 0.90116 to 0.90383, saving model to ../data/resnet34.h5
# Epoch 47/100
# 37/37 [==============================] - 34s 909ms/step - loss: 0.2150 - Dice_Coef: 0.8692 - val_loss: 0.1666 - val_Dice_Coef: 0.8984
#
# Epoch 00047: val_Dice_Coef did not improve from 0.90383
# Epoch 48/100
# 37/37 [==============================] - 33s 903ms/step - loss: 0.2127 - Dice_Coef: 0.8715 - val_loss: 0.1643 - val_Dice_Coef: 0.8992
#
# Epoch 00048: val_Dice_Coef did not improve from 0.90383
# Epoch 49/100
# 37/37 [==============================] - 34s 914ms/step - loss: 0.2180 - Dice_Coef: 0.8690 - val_loss: 0.1618 - val_Dice_Coef: 0.8991
#
# Epoch 00049: val_Dice_Coef did not improve from 0.90383
# Epoch 50/100
# 37/37 [==============================] - 33s 904ms/step - loss: 0.2190 - Dice_Coef: 0.8679 - val_loss: 0.1612 - val_Dice_Coef: 0.8994
#
# Epoch 00050: val_Dice_Coef did not improve from 0.90383
# Epoch 51/100
# 37/37 [==============================] - 34s 907ms/step - loss: 0.2156 - Dice_Coef: 0.8702 - val_loss: 0.1652 - val_Dice_Coef: 0.8974
#
# Epoch 00051: val_Dice_Coef did not improve from 0.90383
# Epoch 52/100
# 37/37 [==============================] - 33s 904ms/step - loss: 0.2197 - Dice_Coef: 0.8684 - val_loss: 0.1622 - val_Dice_Coef: 0.8990
#
# Epoch 00052: val_Dice_Coef did not improve from 0.90383
# Epoch 53/100
# 37/37 [==============================] - 33s 895ms/step - loss: 0.2208 - Dice_Coef: 0.8667 - val_loss: 0.1637 - val_Dice_Coef: 0.8980
#
# Epoch 00053: val_Dice_Coef did not improve from 0.90383
# Epoch 54/100
# 37/37 [==============================] - 33s 892ms/step - loss: 0.2175 - Dice_Coef: 0.8689 - val_loss: 0.1672 - val_Dice_Coef: 0.8962
#
# Epoch 00054: val_Dice_Coef did not improve from 0.90383
# Epoch 55/100
# 37/37 [==============================] - 33s 899ms/step - loss: 0.2151 - Dice_Coef: 0.8708 - val_loss: 0.1642 - val_Dice_Coef: 0.8977
#
# Epoch 00055: val_Dice_Coef did not improve from 0.90383
# Epoch 56/100
# 37/37 [==============================] - 33s 902ms/step - loss: 0.2194 - Dice_Coef: 0.8676 - val_loss: 0.1724 - val_Dice_Coef: 0.8909
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00056: val_Dice_Coef did not improve from 0.90383
# Epoch 57/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2218 - Dice_Coef: 0.8667 - val_loss: 0.1692 - val_Dice_Coef: 0.8959
#
# Epoch 00057: val_Dice_Coef did not improve from 0.90383
# Epoch 58/100
# 37/37 [==============================] - 33s 892ms/step - loss: 0.2140 - Dice_Coef: 0.8701 - val_loss: 0.1657 - val_Dice_Coef: 0.8957
#
# Epoch 00058: val_Dice_Coef did not improve from 0.90383
# Epoch 59/100
# 37/37 [==============================] - 33s 901ms/step - loss: 0.2147 - Dice_Coef: 0.8706 - val_loss: 0.1642 - val_Dice_Coef: 0.8992
#
# Epoch 00059: val_Dice_Coef did not improve from 0.90383
# Epoch 60/100
# 37/37 [==============================] - 33s 899ms/step - loss: 0.2157 - Dice_Coef: 0.8699 - val_loss: 0.1529 - val_Dice_Coef: 0.9044
#
# Epoch 00060: val_Dice_Coef improved from 0.90383 to 0.90438, saving model to ../data/resnet34.h5
# Epoch 61/100
# 37/37 [==============================] - 33s 905ms/step - loss: 0.2158 - Dice_Coef: 0.8702 - val_loss: 0.1576 - val_Dice_Coef: 0.9005
#
# Epoch 00061: val_Dice_Coef did not improve from 0.90438
# Epoch 62/100
# 37/37 [==============================] - 34s 911ms/step - loss: 0.2160 - Dice_Coef: 0.8698 - val_loss: 0.1645 - val_Dice_Coef: 0.8978
#
# Epoch 00062: val_Dice_Coef did not improve from 0.90438
# Epoch 63/100
# 37/37 [==============================] - 33s 896ms/step - loss: 0.2142 - Dice_Coef: 0.8707 - val_loss: 0.1714 - val_Dice_Coef: 0.8928
#
# Epoch 00063: val_Dice_Coef did not improve from 0.90438
# Epoch 64/100
# 37/37 [==============================] - 33s 893ms/step - loss: 0.2175 - Dice_Coef: 0.8686 - val_loss: 0.1670 - val_Dice_Coef: 0.8974
#
# Epoch 00064: val_Dice_Coef did not improve from 0.90438
# Epoch 65/100
# 37/37 [==============================] - 33s 902ms/step - loss: 0.2161 - Dice_Coef: 0.8695 - val_loss: 0.1701 - val_Dice_Coef: 0.8948
#
# Epoch 00065: val_Dice_Coef did not improve from 0.90438
# Epoch 66/100
# 37/37 [==============================] - 32s 876ms/step - loss: 0.2104 - Dice_Coef: 0.8728 - val_loss: 0.1598 - val_Dice_Coef: 0.9020
#
# Epoch 00066: val_Dice_Coef did not improve from 0.90438
# Epoch 67/100
# 37/37 [==============================] - 34s 906ms/step - loss: 0.2164 - Dice_Coef: 0.8703 - val_loss: 0.1628 - val_Dice_Coef: 0.9006
#
# Epoch 00067: val_Dice_Coef did not improve from 0.90438
# Epoch 68/100
# 37/37 [==============================] - 34s 910ms/step - loss: 0.2136 - Dice_Coef: 0.8710 - val_loss: 0.1644 - val_Dice_Coef: 0.8970
#
# Epoch 00068: val_Dice_Coef did not improve from 0.90438
# Epoch 69/100
# 37/37 [==============================] - 33s 902ms/step - loss: 0.2175 - Dice_Coef: 0.8699 - val_loss: 0.1614 - val_Dice_Coef: 0.9003
#
# Epoch 00069: val_Dice_Coef did not improve from 0.90438
# Epoch 70/100
# 37/37 [==============================] - 34s 907ms/step - loss: 0.2175 - Dice_Coef: 0.8685 - val_loss: 0.1583 - val_Dice_Coef: 0.9018
#
# Epoch 00070: val_Dice_Coef did not improve from 0.90438
# Epoch 71/100
# 37/37 [==============================] - 33s 882ms/step - loss: 0.2136 - Dice_Coef: 0.8710 - val_loss: 0.1651 - val_Dice_Coef: 0.8978
#
# Epoch 00071: val_Dice_Coef did not improve from 0.90438
# Epoch 72/100
# 37/37 [==============================] - 33s 893ms/step - loss: 0.2141 - Dice_Coef: 0.8714 - val_loss: 0.1590 - val_Dice_Coef: 0.8998
#
# Epoch 00072: val_Dice_Coef did not improve from 0.90438
# Epoch 73/100
# 37/37 [==============================] - 33s 891ms/step - loss: 0.2187 - Dice_Coef: 0.8683 - val_loss: 0.1588 - val_Dice_Coef: 0.9005
#
# Epoch 00073: val_Dice_Coef did not improve from 0.90438
# Epoch 74/100
# 37/37 [==============================] - 34s 906ms/step - loss: 0.2190 - Dice_Coef: 0.8679 - val_loss: 0.1681 - val_Dice_Coef: 0.8941
#
# Epoch 00074: val_Dice_Coef did not improve from 0.90438
# Epoch 75/100
# 37/37 [==============================] - 32s 871ms/step - loss: 0.2169 - Dice_Coef: 0.8697 - val_loss: 0.1670 - val_Dice_Coef: 0.8972
#
# Epoch 00075: val_Dice_Coef did not improve from 0.90438
# Epoch 76/100
# 30/37 [=======================>......] - ETA: 6s - loss: 0.2133 - Dice_Coef: 0.8703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2b1ac2c10d1c> in <module>
#      20                     validation_data=valid_gen,
#      21                     validation_steps=len(valid_gen),
# ---> 22                     callbacks=callbacks)
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     601                 try:
#     602                     future = self.queue.get(block=True)
# --> 603                     inputs = future.get(timeout=30)
#     604                     self.queue.task_done()
#     605                 except mp.TimeoutError:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
model.load_weights('../data/resnet34.h5')
sample_images, ground_truth_masks = valid_gen.__getitem__(0)
sample_images = sample_images*255.
sample_images = sample_images.astype('uint8')
ground_truth_masks = ground_truth_masks.reshape(BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1])

# %%
predicted_masks = model.predict(sample_images.astype('float32') / 255.)
print(predicted_masks.shape)
# Out:
# (16, 256, 256, 1)

# %%
'''
    Plot images, ground truth masks and predicted masks
'''
predicted_masks_1 = np.array(predicted_masks > 0.5, dtype='uint8').reshape(BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1])
fig, ax = plt.subplots(nrows=3, ncols=5, figsize=(20,10))
i = 0
while i < 5:
    ax[0, i].imshow(sample_images[i])
    ax[1, i].imshow(ground_truth_masks[i])
    ax[2, i].imshow(predicted_masks_1[i])
    ax[0, i].axis('off')
    ax[1, i].axis('off')
    ax[2, i].axis('off')
    i += 1
